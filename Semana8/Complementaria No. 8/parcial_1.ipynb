# %%
# %pip install sympy
# %pip install matplotlib
# %pip install pandas
# %pip install numpy

# %%
from sympy.physics.mechanics import *
from sympy import symbols, pi, sin, cos,  init_printing, Eq, simplify
from sympy.physics.vector import ReferenceFrame
from IPython.display import display

# %% [markdown]
# ## Punto No. 1

# %%
init_printing(use_latex='mathjax')  

t = dynamicsymbols._t
theta = dynamicsymbols('theta')      
l0 = symbols('l0', real=True)
l  = dynamicsymbols('l', real=True) 

N = ReferenceFrame('N')
A = N.orientnew('A', 'Axis', (theta, N.z))
r = (l0 + l) * A.x

# %%
import numpy as np
import matplotlib.pyplot as plt
from sympy import sin, cos, pi
from sympy.physics.mechanics import ReferenceFrame, dynamicsymbols

N = ReferenceFrame('N')
theta = dynamicsymbols('theta')   

A = N.orientnew('A', 'Axis', (theta, N.z))

# %% [markdown]
# ## Punto No. 2

# %%
N = ReferenceFrame('N')

R, Omega, Alpha, theta = symbols('R Omega Alpha theta')

# %% [markdown]
# ## Punto 3

# %%
from sympy import symbols, sqrt, lambdify
import numpy as np
import matplotlib.pyplot as plt

L, x, vB = symbols('L x vB', positive=True)

# %% [markdown]
# ## Punto 4

# %%
from sympy import symbols, Eq, cos, sin, sqrt, simplify, solve
from sympy.physics.mechanics import dynamicsymbols, ReferenceFrame

t = dynamicsymbols._t
L1, L2, x_c, sigma = symbols('L1 L2 x_c sigma', positive=True)
theta1, theta2, s = dynamicsymbols('theta1 theta2 s') # s es h 
theta1d, theta2d, sd = theta1.diff(), theta2.diff(), s.diff()

N = ReferenceFrame('N')
A = N.orientnew('A','Axis',(theta1, N.z))
C = N.orientnew('C','Axis',(theta2, N.z))

r_OA = L1 * A.x # pivote a punto de mango
r_AB = L2 * C.x # pasador del mango a eslabon 2
r_OB = x_c * N.x + s * N.y # como el pin se encuentra en la prismatica comparten alturas con esta

# (r_OA + r_AB - r_OB = 0)
pos_x = Eq((r_OA + r_AB - r_OB).dot(N.x), 0)
pos_y = Eq((r_OA + r_AB - r_OB).dot(N.y), 0)
